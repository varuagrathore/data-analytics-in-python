# %%
import pandas as pd

# %%
var=pd.read_csv("Diwali Sales Data.csv",sep=',',encoding='unicode_escape')
var
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
pd.set_option('display.max_columns',15)
pd.set_option('display.max_rows',85)

# %%
var
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
var.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
var.shape
# Out:
# (11251, 15)

# %%
var.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %% [markdown]
# NOW GIVE ANSWER TO SOME QUESTION

# %% [markdown]
# How many rows are there in the DataFrame?

# %%
var.shape[0]
# Out:
# 11251

# %% [markdown]
# How many columns are there in the DataFrame?

# %%
var.shape[1]
# Out:
# 15

# %% [markdown]
# Display the first 5 rows of the DataFrame

# %%
var.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# Display the last 5 rows of the DataFrame.

# %%
var.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %% [markdown]
# What is the data type of the 'Age' column?

# %%
var.dtypes['Age']
# Out:
# dtype('int64')

# %% [markdown]
# Calculate the average age of the customers.

# %%
var['Age'].mean()
# Out:
# 35.421207003821884

# %% [markdown]
# Find the unique values in the 'Gender' column

# %%
var['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# How many unique products are there in the 'Product_ID' column?

# %%
var['Product_ID'].unique()
# Out:
# array(['P00125942', 'P00110942', 'P00118542', ..., 'P00307142',
#        'P00044742', 'P00296942'], dtype=object)

# %% [markdown]
# What are the different 'Marital_Status' values in the DataFrame?

# %%
var['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# How many unique 'Product_IDs' are purchased by 'Married' customers?

# %%
var[var['Marital_Status']==1]['Product_ID'].unique()
# Out:
# array(['P00110942', 'P00118542', 'P00057942', ..., 'P00307142',
#        'P00185442', 'P00296942'], dtype=object)

# %% [markdown]
# Calculate the total 'Amount' for each 'State'

# %%
var.groupby('State')['Amount'].sum()
# Out:
# State
# Andhra Pradesh       8037146.99
# Bihar                4022757.00
# Delhi               11603819.45
# Gujarat              3946082.00
# Haryana              4220175.00
# Himachal Pradesh     4963368.00
# Jharkhand            3026456.00
# Karnataka           13523540.00
# Kerala               3894491.99
# Madhya Pradesh       8101142.00
# Maharashtra         14427543.00
# Punjab               1525800.00
# Rajasthan            1909409.00
# Telangana            1151490.00
# Uttar Pradesh       19374968.00
# Uttarakhand          2520944.00
# Name: Amount, dtype: float64

# %% [markdown]
# **Data Selection and Filtering:**

# %% [markdown]
# Select only the 'User_ID' and 'Product_ID' columns

# %%
var[['User_ID','Product_ID']]
# Out:
#        User_ID Product_ID
# 0      1002903  P00125942
# 1      1000732  P00110942
# 2      1001990  P00118542
# 3      1001425  P00237842
# 4      1000588  P00057942
# ...        ...        ...
# 11246  1000695  P00296942
# 11247  1004089  P00171342
# 11248  1001209  P00201342
# 11249  1004023  P00059442
# 11250  1002744  P00281742
#
# [11251 rows x 2 columns]

# %% [markdown]
# Create a new DataFrame with only the rows where 'Gender' is 'Male'

# %%
var_new=var[var['Gender']=='M']
var_new
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# 5      1000588         Joni  P00057942      M     26-35   28               1
# 8      1003224       Kushal  P00205642      M     26-35   35               0
# 10     1003829     Harshita  P00200842      M     26-35   34               0
# ...        ...          ...        ...    ...       ...  ...             ...
# 11243  1005446      Sheetal  P00297742      M     51-55   53               0
# 11244  1005446      Sheetal  P00297742      M     51-55   53               0
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
#
# ...

# %% [markdown]
# Filter the data to show rows with 'Age' greater than or equal to 30.

# %%
Age_new=var[var['Age']>=30]

# %%
Age_new
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 7      1002092     Shivangi  P00273442      F       55+   61               0
# 8      1003224       Kushal  P00205642      M     26-35   35               0
# 10     1003829     Harshita  P00200842      M     26-35   34               0
# ...        ...          ...        ...    ...       ...  ...             ...
# 11244  1005446      Sheetal  P00297742      M     51-55   53               0
# 11245  1004140    Bertelson  P00057442      F     26-35   31               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
#
# ...

# %% [markdown]
# Find all the records of customers who made more than 5 'Orders'.

# %%
new_orders=var[var['Orders']>5]

# %%
new_orders
# Out:
# Empty DataFrame
# Columns: [User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Marital_Status, State, Zone, Occupation, Product_Category, Orders, Amount, Status, unnamed1]
# Index: []

# %% [markdown]
# Display all records for customers in the 'West' 'Zone'.

# %%
customer_west=var[var['Zone']=="Western"]

# %%
customer_west
# Out:
#        User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903  Sanskriti  P00125942      F     26-35   28               0
# 4      1000588       Joni  P00057942      M     26-35   28               1
# 7      1002092   Shivangi  P00273442      F       55+   61               0
# 33     1002638     Damala  P00346242      F     26-35   35               1
# 60     1000379      Thais  P00121642      M     36-45   39               0
# ...        ...        ...        ...    ...       ...  ...             ...
# 11223  1001542       Buch  P00113642      F     18-25   20               1
# 11233  1002106       Luke  P00164342      M     18-25   19               0
# 11243  1005446    Sheetal  P00297742      M     51-55   53               0
# 11246  1000695    Manning  P00296942      M     18-25   19               1
# 11250  1002744    Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# Show data for customers who are 'Single' (Marital_Status) and 'Female' (Gender)

# %%
data=var[(var['Marital_Status']==0)&(var['Gender']=='F')]

# %%
data
# Out:
#        User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903  Sanskriti  P00125942      F     26-35   28               0
# 7      1002092   Shivangi  P00273442      F       55+   61               0
# 11     1000214   Kargatis  P00119142      F     18-25   20               0
# 15     1000813     Lauren  P00289942      F     18-25   24               0
# 17     1001193       Mick  P00004842      F     26-35   29               0
# ...        ...        ...        ...    ...       ...  ...             ...
# 11239  1000802     Marley  P00245642      F     26-35   33               0
# 11240  1001425     Sudevi  P00044742      F      0-17   12               0
# 11241  1003032   Matthias  P00058042      F     26-35   33               0
# 11248  1001209      Oshin  P00201342      F     36-45   40               0
# 11250  1002744    Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# Display records for 'Male' customers aged 18 to 25.

# %%
Age_Male=var[(var['Gender']=='M')&(var['Age']>18)&(var['Age']<25)]
Age_Male
# Out:
#        User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 36     1005649      Sweta  P00238542      M     18-25   20               1
# 63     1000423    Saurabh  P00046742      M     18-25   21               0
# 67     1004489       Pete  P00216742      M     18-25   20               0
# 68     1001865       Cyra  P00213742      M     18-25   23               1
# 74     1003618     Keshav  P00248942      M     18-25   19               1
# ...        ...        ...        ...    ...       ...  ...             ...
# 11187  1000242      Henry  P00014642      M     18-25   21               0
# 11200  1000814      Hwang  P00144042      M     18-25   19               0
# 11214  1003971  Selesnick  P00329442      M     18-25   21               0
# 11233  1002106       Luke  P00164342      M     18-25   19               0
# 11246  1000695    Manning  P00296942      M     18-25   19               1
#
# ...

# %% [markdown]
# Show data for customers from 'New York' (State) who purchased 'Electronics' (Product_Category).

# %%
var[(var['State']=='New York')&(var['Product_Category']=='Electronics')]
# Out:
# Empty DataFrame
# Columns: [User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Marital_Status, State, Zone, Occupation, Product_Category, Orders, Amount, Status, unnamed1]
# Index: []

# %%
var[var['State']=='New York']
# Out:
# Empty DataFrame
# Columns: [User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Marital_Status, State, Zone, Occupation, Product_Category, Orders, Amount, Status, unnamed1]
# Index: []

# %% [markdown]
# **Data Aggregation and Summary**

# %% [markdown]
# Calculate the total number of orders.

# %%
var['Orders'].count()
# Out:
# 11251

# %% [markdown]
# What is the total amount spent by all customers?

# %%
var['Amount'].sum()
# Out:
# 106249132.43

# %% [markdown]
# Find the maximum age in the dataset

# %%
var['Age'].max()
# Out:
# 92

# %% [markdown]
# Calculate the average amount spent by 'Male' and 'Female' customers.

# %%
var.groupby('Gender')['Amount'].mean()
# Out:
# Gender
# F    9491.299340
# M    9366.972703
# Name: Amount, dtype: float64

# %% [markdown]
# Group the data by 'Zone' and find the average 'Amount' spent in each zone.

# %%
var.groupby('Zone')['Amount'].mean()
# Out:
# Zone
# Central     9699.434239
# Eastern     8659.966830
# Northern    8463.281019
# Southern    9879.936495
# Western     9412.717725
# Name: Amount, dtype: float64

# %% [markdown]
# Find the most common 'Occupation' in the dataset

# %%
var['Occupation'].mode()
# Out:
# 0    IT Sector
# Name: Occupation, dtype: object

# %% [markdown]
# Calculate the sum of 'Orders' for each 'Product_Category'

# %%
var.groupby('Product_Category')['Orders'].sum()
# Out:
# Product_Category
# Auto                      246
# Beauty                   1086
# Books                     245
# Clothing & Apparel       6634
# Decor                     235
# Electronics & Gadgets    5226
# Food                     6120
# Footwear & Shoes         2654
# Furniture                 890
# Games & Toys              940
# Hand & Power Tools         80
# Household items          1331
# Office                    261
# Pet Care                  536
# Sports Products           870
# Stationery                281
# Tupperware                166
# Veterinary                206
# Name: Orders, dtype: int64

# %% [markdown]
# Determine the median age of 'Single' customers.

# %%
var[var['Marital_Status']==0]['Age'].median()
# Out:
# 33.0

# %% [markdown]
# How many unique 'Product_IDs' are purchased by 'Married' customers?

# %%
var[var['Marital_Status']==1]['Product_ID'].unique()
# Out:
# array(['P00110942', 'P00118542', 'P00057942', ..., 'P00307142',
#        'P00185442', 'P00296942'], dtype=object)

# %% [markdown]
# Calculate the total 'Amount' for each 'State'

# %%
var.groupby('State')['Amount'].sum()
# Out:
# State
# Andhra Pradesh       8037146.99
# Bihar                4022757.00
# Delhi               11603819.45
# Gujarat              3946082.00
# Haryana              4220175.00
# Himachal Pradesh     4963368.00
# Jharkhand            3026456.00
# Karnataka           13523540.00
# Kerala               3894491.99
# Madhya Pradesh       8101142.00
# Maharashtra         14427543.00
# Punjab               1525800.00
# Rajasthan            1909409.00
# Telangana            1151490.00
# Uttar Pradesh       19374968.00
# Uttarakhand          2520944.00
# Name: Amount, dtype: float64
